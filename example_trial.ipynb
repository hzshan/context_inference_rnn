# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import task_generation as taskgen

# %%
# trial, boundaries, epochs = taskgen.make_go_trial(0, 0.01)
# trial, boundaries, epochs = taskgen.make_decision_making_trial(0, 0.01)
trial, boundaries, epochs = taskgen.make_order_trial(0, 0.01)
# trial, boundaries, epochs = taskgen.make_anti_epoch(0, 0.01)

labels = ['stim cos', 'stim sin', 'fixation']

_, axes = plt.subplots(nrows=3, ncols=1, sharex=True)
axes = axes.ravel()
for i in range(3):
    axes[i].plot(trial['s'][i])
    axes[i].set_ylim(-0.2, 1.2)
    for b in boundaries:
        axes[i].axvline(b, color='k', linestyle='--')
    axes[i].set_ylabel(labels[i])
plt.xlabel('timesteps')
plt.suptitle(epochs)
# Out:
# Text(0.5, 0.98, 'F->S_P->S_D->R')
