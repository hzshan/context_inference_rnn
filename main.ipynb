# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import task_generation as taskgen
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pro_trial, boundaries = taskgen.generate_go_trial(0, 0.01)
labels = ['stim1 cos', 'stim1 sin', 'stim2 cos', 'stim2 sin', 'fixation']

_, axes = plt.subplots(nrows=5, ncols=1, sharex=True)
axes = axes.ravel()
for i in range(5):
    axes[i].plot(pro_trial['s'][i])
    axes[i].set_ylim(-1.2, 1.2)
    for b in boundaries:
        axes[i].axvline(b, color='k', linestyle='--')
    axes[i].set_ylabel(labels[i])
plt.xlabel('timesteps')
# Out:
# Text(0.5, 0, 'timesteps')

# %%
get_input(0, 1, 1, 10, 0.1).shape
# Out:
# (10, 3, 2)

# %%
pro_trial.shape
# Out:
# (266, 3, 2)

# %%
pro_trial = generate_pro_trial([0, 1], 0.1)

plt.figure()
plt.plot(pro_trial[:, 0, 0], pro_trial[:, 0, 1], 'r')

# %%
lam = 0.01
beta = 1 / np.log(1 - lam)

exp_samples = np.random.geometric(lam, 10000)

poisson_samples = [sample_transition(lam) for _ in range(10000)]

plt.figure()
plt.hist(exp_samples, bins=50)
plt.hist(poisson_samples, bins=50, alpha=0.5)
# Out:
# (array([1.763e+03, 1.424e+03, 1.157e+03, 1.052e+03, 8.060e+02, 6.700e+02,
#         5.290e+02, 4.750e+02, 3.590e+02, 3.010e+02, 2.850e+02, 2.330e+02,
#         1.370e+02, 1.370e+02, 1.270e+02, 8.900e+01, 7.000e+01, 8.000e+01,
#         4.800e+01, 5.000e+01, 3.700e+01, 3.200e+01, 2.500e+01, 2.000e+01,
#         1.800e+01, 1.500e+01, 7.000e+00, 9.000e+00, 1.000e+01, 4.000e+00,
#         5.000e+00, 7.000e+00, 4.000e+00, 1.000e+00, 3.000e+00, 2.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 2.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  0.  ,  19.26,  38.52,  57.78,  77.04,  96.3 , 115.56, 134.82,
#         154.08, 173.34, 192.6 , 211.86, 231.12, 250.38, 269.64, 288.9 ,
#         308.16, 327.42, 346.68, 365.94, 385.2 , 404.46, 423.72, 442.98,
#         462.24, 481.5 , 500.76, 520.02, 539.28, 558.54, 577.8 , 597.06,
# ...
